# %% [markdown]
# # Pre-production Environment

# %% [markdown]
# I use this file to write *advanced* coding information, including *mathematical formulas*, and to test the code before I put it into the main file.

# %% [markdown]
# ## Table Extraction from Images: Experimental Data Analysis
#
# ### 1. Importing the Libraries

# %%
# !pip install tabula-py
# %pip install tabulate
# Out:
# ...
#   Using cached tabula_py-2.7.0-py3-none-any.whl (12.0 MB)
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tabula.io import read_pdf
from tabulate import tabulate
import pandas as pd
import io

# Read the only the page n°6 of the file
food_calories = read_pdf('./Data/Table.png',pages = "all")

# Transform the result into a string table format
table = tabulate(food_calories)

# Transform the table into dataframe
df = pd.read_fwf(io.StringIO(table))

# Save the final result as excel file
df.to_excel("./Data/Table.xlsx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 7
#       4 import io
#       6 # Read the only the page n°6 of the file
# ----> 7 food_calories = tabula.read_pdf('./Data/Table.png',pages = "all")
#       9 # Transform the result into a string table format
#      10 table = tabulate(food_calories)
#
# AttributeError: module 'tabula' has no attribute 'read_pdf'
